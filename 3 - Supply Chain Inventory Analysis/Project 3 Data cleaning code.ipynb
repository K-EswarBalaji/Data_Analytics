# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-523566ef-3ee8-4a77-9a89-0548e12b274d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-523566ef-3ee8-4a77-9a89-0548e12b274d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_excel("supply_chain_inventory_dataset_15000_rows 2.xlsx")
df
# Out:
#       Product_ID Product_Name     Category Supplier_Name Order_Date  \
# 0       PROD1000       Tablet      Fashion    Supplier D 2023-08-02
# 1       PROD1001       Tablet      Fashion    Supplier D 2024-04-11
# 2       PROD1002        Mixer       Sports    Supplier A 2024-08-16
# 3       PROD1003           TV       Sports    Supplier B 2024-11-30
# 4       PROD1004        Mixer      Fashion    Supplier C 2024-08-03
# ...          ...          ...          ...           ...        ...
# 14995  PROD15995        Shoes      Fashion    Supplier E 2024-03-03
# 14996  PROD15996           TV      Fashion    Supplier D 2023-06-22
# 14997  PROD15997       Tablet  Electronics    Supplier D 2024-06-22
# 14998  PROD15998       Camera  Electronics    Supplier D 2024-10-06
# 14999  PROD15999       Tablet       Sports    Supplier C 2023-05-02
#
#       Delivery_Date  Stock_Quantity  Reorder_Level  Units_Sold  Purchase_Cost  \
# ...

# %%
df.shape
# Out:
# (15000, 13)

# %%
df.describe()
# Out:
#                        Order_Date               Delivery_Date  Stock_Quantity  \
# count                       15000                       15000    15000.000000
# mean   2023-12-28 15:20:09.600000  2024-01-03 03:14:35.520000      250.917933
# min           2023-01-01 00:00:00         2023-01-02 00:00:00        0.000000
# 25%           2023-06-26 00:00:00         2023-07-02 00:00:00      126.000000
# 50%           2023-12-26 00:00:00         2023-12-31 00:00:00      251.000000
# 75%           2024-07-01 00:00:00         2024-07-07 00:00:00      375.000000
# max           2024-12-31 00:00:00         2025-01-10 00:00:00      500.000000
# std                           NaN                         NaN      144.554751
#
#        Reorder_Level    Units_Sold  Purchase_Cost  Selling_Price  \
# count   15000.000000  15000.000000   15000.000000   15000.000000
# mean       99.802467    148.167200    1102.676733    1378.474133
# min        50.000000      0.000000     200.000000     263.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Product_ID          15000 non-null  object
#  1   Product_Name        15000 non-null  object
#  2   Category            15000 non-null  object
#  3   Supplier_Name       15000 non-null  object
#  4   Order_Date          15000 non-null  datetime64[ns]
#  5   Delivery_Date       15000 non-null  datetime64[ns]
#  6   Stock_Quantity      15000 non-null  int64
#  7   Reorder_Level       15000 non-null  int64
#  8   Units_Sold          15000 non-null  int64
#  9   Purchase_Cost       15000 non-null  int64
#  10  Selling_Price       15000 non-null  int64
#  11  Warehouse_Location  15000 non-null  object
#  12  Shipping_Time_Days  15000 non-null  int64
# dtypes: datetime64[ns](2), int64(6), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# No Null Values

# %%
df.isnull().sum()
# Out:
# Product_ID            0
# Product_Name          0
# Category              0
# Supplier_Name         0
# Order_Date            0
# Delivery_Date         0
# Stock_Quantity        0
# Reorder_Level         0
# Units_Sold            0
# Purchase_Cost         0
# Selling_Price         0
# Warehouse_Location    0
# Shipping_Time_Days    0
# dtype: int64

# %% [markdown]
# No Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
np.dtype(df['Delivery_Date'])
# Out:
# dtype('<M8[ns]')

# %%
np.dtype(df['Order_Date'])
# Out:
# dtype('<M8[ns]')

# %%
# Out:
# dtype('int64')

# %% [markdown]
# Ensure numeric columns are properly formatted

# %%
numerical_cols = ["Stock_Quantity","Reorder_Level","Units_Sold","Purchase_Cost","Selling_Price","Shipping_Time_Days"]
for col in numerical_cols:
  df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
df[df["Stock_Quantity"] < 0]
# Out:
# Empty DataFrame
# Columns: [Product_ID, Product_Name, Category, Supplier_Name, Order_Date, Delivery_Date, Stock_Quantity, Reorder_Level, Units_Sold, Purchase_Cost, Selling_Price, Warehouse_Location, Shipping_Time_Days]
# Index: []

# %% [markdown]
# No negative or incorrect stock values

# %%
df.to_excel("cleaned_data_set.xlsx",index = False)
print("Data Cleaning Completed")
# Out:
# Data Cleaning Completed

# %%
from google.colab import files
files.download("cleaned_data_set.xlsx")
